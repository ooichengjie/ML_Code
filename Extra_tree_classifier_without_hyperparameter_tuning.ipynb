# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# #Import the libary to deal with tabular data and visualization
# import pandas as pd
# import matplotlib.pyplot as plt
# import numpy as np
# from sklearn.model_selection import train_test_split
# from sklearn.linear_model import LogisticRegression
#
# %matplotlib inline
# %matplotlib notebook

# %%
#Import the libary to deal with tabular data and visualization
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %matplotlib inline
# %matplotlib notebook

# %%
#Import the dataset
reproduce_df = pd.read_csv('ObesityDataSet_raw_and_data_sinthetic.csv')
#reproduce_df=pd.read_csv('Madedata1.csv')

# %%
#Data cleaning
#https://towardsdatascience.com/data-cleaning-with-python-and-pandas-detecting-missing-values-3e9c6ebcf78b
#Summarizing Missing Values
#check if any missing value in the dataset
reproduce_df.isna().sum()
# Out:
# Gender                            0
# Age                               0
# Height                            0
# Weight                            0
# family_history_with_overweight    0
# FAVC                              0
# FCVC                              0
# NCP                               0
# CAEC                              0
# SMOKE                             0
# CH2O                              0
# SCC                               0
# FAF                               0
# TUE                               0
# CALC                              0
# MTRANS                            0
# NObeyesdad                        0
# dtype: int64

# %%
#TABLE 1. Patients information dataset
#glance at raw dataset first and last few rows 
reproduce_df.head(2)
# Out:
#    Gender   Age  Height  Weight family_history_with_overweight FAVC  FCVC  \
# 0  Female  21.0    1.62    64.0                            yes   no   2.0
# 1  Female  21.0    1.52    56.0                            yes   no   3.0
#
#    NCP       CAEC SMOKE  CH2O  SCC  FAF  TUE       CALC  \
# 0  3.0  Sometimes    no   2.0   no  0.0  1.0         no
# 1  3.0  Sometimes   yes   3.0  yes  3.0  0.0  Sometimes
#
#                   MTRANS     NObeyesdad
# 0  Public_Transportation  Normal_Weight
# 1  Public_Transportation  Normal_Weight

# %%
reproduce_df.isna().sum()
# Out:
# Gender                            0
# Age                               0
# Height                            0
# Weight                            0
# family_history_with_overweight    0
# FAVC                              0
# FCVC                              0
# NCP                               0
# CAEC                              0
# SMOKE                             0
# CH2O                              0
# SCC                               0
# FAF                               0
# TUE                               0
# CALC                              0
# MTRANS                            0
# NObeyesdad                        0
# dtype: int64

# %%
reproduce_df.columns = ['Gender', 'Age', 'Height', 'Weight', 'Family_History',
       'Consumption_high_caloric', 'Consumption_vegetables', 'Main_meals', 'Food_between_meals', 'Smoke', 'Consumption_water', 'Calories_monitoring', 'Physical_activity', 'Technology_devices',
       'Consumption_alcohol', 'Transportation', 'Obesity']

reproduce_df.head(80)
# Out:
#     Gender   Age  Height  Weight Family_History Consumption_high_caloric  \
# 0   Female  21.0    1.62    64.0            yes                       no
# 1   Female  21.0    1.52    56.0            yes                       no
# 2     Male  23.0    1.80    77.0            yes                       no
# 3     Male  27.0    1.80    87.0             no                       no
# 4     Male  22.0    1.78    89.8             no                       no
# ..     ...   ...     ...     ...            ...                      ...
# 75  Female  23.0    1.63    45.0            yes                       no
# 76  Female  24.0    1.60    45.0            yes                       no
# 77  Female  24.0    1.70    80.0            yes                      yes
# 78  Female  23.0    1.65    90.0            yes                      yes
# 79    Male  23.0    1.65    60.0            yes                       no
#
#     Consumption_vegetables  Main_meals Food_between_meals Smoke  \
# 0                      2.0         3.0          Sometimes    no
# 1                      3.0         3.0          Sometimes   yes
# 2                      2.0         3.0          Sometimes    no
# 3                      3.0         3.0          Sometimes    no
# 4                      2.0         1.0          Sometimes    no
# ..                     ...         ...                ...   ...
# 75                     3.0         3.0          Sometimes    no
# 76                     2.0         3.0                 no    no
# 77                     2.0         3.0          Sometimes    no
# 78                     2.0         3.0          Sometimes    no
# 79                     2.0         3.0          Sometimes    no
#
#     Consumption_water Calories_monitoring  Physical_activity  \
# 0                 2.0                  no                0.0
# 1                 3.0                 yes                3.0
# 2                 2.0                  no                2.0
# 3                 2.0                  no                2.0
# 4                 2.0                  no                0.0
# ..                ...                 ...                ...
# 75                3.0                 yes                2.0
# 76                2.0                  no                1.0
# 77                3.0                  no                0.0
# 78                3.0                  no                0.0
# 79                2.0                  no                0.0
#
#     Technology_devices Consumption_alcohol         Transportation  \
# 0                  1.0                  no  Public_Transportation
# 1                  0.0           Sometimes  Public_Transportation
# 2                  1.0          Frequently  Public_Transportation
# 3                  0.0          Frequently                Walking
# 4                  0.0           Sometimes  Public_Transportation
# ..                 ...                 ...                    ...
# 75                 0.0                  no  Public_Transportation
# 76                 0.0                  no  Public_Transportation
# 77                 0.0                  no  Public_Transportation
# 78                 1.0                  no  Public_Transportation
# 79                 0.0           Sometimes  Public_Transportation
#
#                 Obesity
# 0         Normal_Weight
# 1         Normal_Weight
# 2         Normal_Weight
# 3    Overweight_Level_I
# 4   Overweight_Level_II
# ..                  ...
# 75  Insufficient_Weight
# 76  Insufficient_Weight
# 77  Overweight_Level_II
# 78       Obesity_Type_I
# 79        Normal_Weight
#
# [80 rows x 17 columns]

# %%
reproduce_df['Obesity'] = reproduce_df['Obesity'].apply(lambda x: x.replace('_', ''))
reproduce_df['Transportation'] = reproduce_df['Transportation'].apply(lambda x: x.replace('_', ' '))
reproduce_df['Height'] = reproduce_df['Height']*100
reproduce_df['Height'] = reproduce_df['Height'].round(2)
reproduce_df['Weight'] = reproduce_df['Weight'].round(1)
reproduce_df['Age'] = reproduce_df['Age'].round(1)

# %%
pd.set_option('display.max_columns', None)
reproduce_df.head(6)
# Out:
#    Gender   Age  Height  Weight Family_History Consumption_high_caloric  \
# 0  Female  21.0   162.0    64.0            yes                       no
# 1  Female  21.0   152.0    56.0            yes                       no
# 2    Male  23.0   180.0    77.0            yes                       no
# 3    Male  27.0   180.0    87.0             no                       no
# 4    Male  22.0   178.0    89.8             no                       no
# 5    Male  29.0   162.0    53.0             no                      yes
#
#    Consumption_vegetables  Main_meals Food_between_meals Smoke  \
# 0                     2.0         3.0          Sometimes    no
# 1                     3.0         3.0          Sometimes   yes
# 2                     2.0         3.0          Sometimes    no
# 3                     3.0         3.0          Sometimes    no
# 4                     2.0         1.0          Sometimes    no
# 5                     2.0         3.0          Sometimes    no
#
#    Consumption_water Calories_monitoring  Physical_activity  \
# 0                2.0                  no                0.0
# 1                3.0                 yes                3.0
# 2                2.0                  no                2.0
# 3                2.0                  no                2.0
# 4                2.0                  no                0.0
# 5                2.0                  no                0.0
#
#    Technology_devices Consumption_alcohol         Transportation  \
# 0                 1.0                  no  Public Transportation
# 1                 0.0           Sometimes  Public Transportation
# 2                 1.0          Frequently  Public Transportation
# 3                 0.0          Frequently                Walking
# 4                 0.0           Sometimes  Public Transportation
# 5                 0.0           Sometimes             Automobile
#
#              Obesity
# 0       NormalWeight
# 1       NormalWeight
# 2       NormalWeight
# 3   OverweightLevelI
# 4  OverweightLevelII
# 5       NormalWeight

# %%
for x in ['Age','Height','Weight','Consumption_vegetables', 'Main_meals', 'Consumption_water', 'Physical_activity', 'Technology_devices']:
    value = np.array(reproduce_df[x])
    print(x,':', 'min:', np.min(value), 'max:', np.max(value))
# Out:
# Age : min: 14.0 max: 61.0
# Height : min: 145.0 max: 198.0
# Weight : min: 39.0 max: 173.0
# Consumption_vegetables : min: 1.0 max: 3.0
# Main_meals : min: 1.0 max: 4.0
# Consumption_water : min: 1.0 max: 3.0
# Physical_activity : min: 0.0 max: 3.0
# Technology_devices : min: 0.0 max: 2.0

# %%
# identity categorical variables (data type would be 'object')
cat = reproduce_df.dtypes == object
print(cat)
# When dtype == object is 'true'
print(cat[cat])
cat_labels = cat[cat].index
print('Categorical variables:', cat_labels)

# When dtype == object is 'false'
false = cat[~cat]
non_cat = false.index
print('Numerical variables:', non_cat)
# Out:
# Gender                       True
# Age                         False
# Height                      False
# Weight                      False
# Family_History               True
# Consumption_high_caloric     True
# Consumption_vegetables      False
# Main_meals                  False
# Food_between_meals           True
# Smoke                        True
# Consumption_water           False
# Calories_monitoring          True
# Physical_activity           False
# Technology_devices          False
# Consumption_alcohol          True
# Transportation               True
# Obesity                      True
# dtype: bool
# Gender                      True
# Family_History              True
# Consumption_high_caloric    True
# Food_between_meals          True
# Smoke                       True
# Calories_monitoring         True
# Consumption_alcohol         True
# Transportation              True
# Obesity                     True
# dtype: bool
# Categorical variables: Index(['Gender', 'Family_History', 'Consumption_high_caloric',
#        'Food_between_meals', 'Smoke', 'Calories_monitoring',
#        'Consumption_alcohol', 'Transportation', 'Obesity'],
#       dtype='object')
# Numerical variables: Index(['Age', 'Height', 'Weight', 'Consumption_vegetables', 'Main_meals',
#        'Consumption_water', 'Physical_activity', 'Technology_devices'],
#       dtype='object')

# %%
for col in reproduce_df.select_dtypes('object'):
    print(f'{col:-<40} {reproduce_df[col].unique()}')
# Out:
# Gender---------------------------------- ['Female' 'Male']
# Family_History-------------------------- ['yes' 'no']
# Consumption_high_caloric---------------- ['no' 'yes']
# Food_between_meals---------------------- ['Sometimes' 'Frequently' 'Always' 'no']
# Smoke----------------------------------- ['no' 'yes']
# Calories_monitoring--------------------- ['no' 'yes']
# Consumption_alcohol--------------------- ['no' 'Sometimes' 'Frequently' 'Always']
# Transportation-------------------------- ['Public Transportation' 'Walking' 'Automobile' 'Motorbike' 'Bike']
# Obesity--------------------------------- ['NormalWeight' 'OverweightLevelI' 'OverweightLevelII' 'ObesityTypeI'
#  'InsufficientWeight' 'ObesityTypeII' 'ObesityTypeIII']

# %%
import warnings
warnings.filterwarnings("ignore")

import seaborn as sns
plt.figure()
a=sns.distplot(reproduce_df.Age)
a.figure.savefig("Age.png")
plt.show()

plt.figure()
b=sns.distplot(reproduce_df.Weight)
b.figure.savefig("Weight.png")
plt.show()

plt.figure()
c=sns.distplot(reproduce_df.Height)
c.figure.savefig("Height.png")
plt.show()

plt.figure()
k=sns.distplot(reproduce_df.Consumption_vegetables)
k.figure.savefig("Consumption_vegetables.png")
plt.show()

    
import seaborn as sns
plt.figure()
l=sns.distplot(reproduce_df.Main_meals)
l.figure.savefig("Main_meals.png")
plt.show()

import seaborn as sns
plt.figure()
m=sns.distplot(reproduce_df.Consumption_water)
m.figure.savefig("Consumption_water.png")
plt.show()

import seaborn as sns
plt.figure()
n=sns.distplot(reproduce_df.Physical_activity)
n.figure.savefig("Physical_activity.png")
plt.show()

import seaborn as sns
plt.figure()
o=sns.distplot(reproduce_df.Technology_devices)
o.figure.savefig("Technology_devices.png")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="431.818172458775">
# <img src="data:image/png;base64,..." width="431.818172458775">
# <img src="data:image/png;base64,..." width="431.818172458775">
# <img src="data:image/png;base64,..." width="431.818172458775">
# <img src="data:image/png;base64,..." width="431.818172458775">
# <img src="data:image/png;base64,..." width="431.818172458775">
# <img src="data:image/png;base64,..." width="392.7272642151385">
# <img src="data:image/png;base64,..." width="392.7272642151385">

# %%
import seaborn as sns

# %%
mapping1 = {'no':0, 'yes':1}
mapping2 = {'no':1,'Sometimes':2,'Frequently':3,'Always':4}
mapping3 = {'InsufficientWeight':0,'NormalWeight':1,'OverweightLevelI':2,'OverweightLevelII':3,'ObesityTypeI':4
,'ObesityTypeII':5,'ObesityTypeIII':6}

# %%
reproduce_df['Family_History'] = reproduce_df['Family_History'].replace(mapping1)
reproduce_df['Consumption_high_caloric'] = reproduce_df['Consumption_high_caloric'].replace(mapping1)
reproduce_df['Food_between_meals'] = reproduce_df['Food_between_meals'].replace(mapping2)
reproduce_df['Smoke'] = reproduce_df['Smoke'].replace(mapping1)
reproduce_df['Calories_monitoring'] = reproduce_df['Calories_monitoring'].replace(mapping1)
reproduce_df['Consumption_alcohol'] = reproduce_df['Consumption_alcohol'].replace(mapping2)
reproduce_df['Obesity'] = reproduce_df['Obesity'].replace(mapping3)

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OrdinalEncoder

enc = OrdinalEncoder()
enc.fit(reproduce_df[["Gender","Transportation"]])
reproduce_df[["Gender","Transportation"]] = enc.transform(reproduce_df[["Gender","Transportation"]])
#le = LabelEncoder()
#reproduce_df.Gender= le.fit_transform(reproduce_df['Gender'])
#reproduce_df.Transportation= le.fit_transform(reproduce_df['Transportation'])
#reproduce_df.Obesity= le.fit_transform(reproduce_df['Obesity'])
#reproduce_df = pd.concat([reproduce_df,pd.get_dummies(reproduce_df.Transportation).add_prefix('Transportation')],axis=1)

# %%
reproduce_df.head(6)
# Out:
#    Gender   Age  Height  Weight  Family_History  Consumption_high_caloric  \
# 0     0.0  21.0   162.0    64.0               1                         0
# 1     0.0  21.0   152.0    56.0               1                         0
# 2     1.0  23.0   180.0    77.0               1                         0
# 3     1.0  27.0   180.0    87.0               0                         0
# 4     1.0  22.0   178.0    89.8               0                         0
# 5     1.0  29.0   162.0    53.0               0                         1
#
#    Consumption_vegetables  Main_meals  Food_between_meals  Smoke  \
# 0                     2.0         3.0                   2      0
# 1                     3.0         3.0                   2      1
# 2                     2.0         3.0                   2      0
# 3                     3.0         3.0                   2      0
# 4                     2.0         1.0                   2      0
# 5                     2.0         3.0                   2      0
#
#    Consumption_water  Calories_monitoring  Physical_activity  \
# 0                2.0                    0                0.0
# 1                3.0                    1                3.0
# 2                2.0                    0                2.0
# 3                2.0                    0                2.0
# 4                2.0                    0                0.0
# 5                2.0                    0                0.0
#
#    Technology_devices  Consumption_alcohol  Transportation  Obesity
# 0                 1.0                    1             3.0        1
# 1                 0.0                    2             3.0        1
# 2                 1.0                    3             3.0        1
# 3                 0.0                    3             4.0        2
# 4                 0.0                    2             3.0        3
# 5                 0.0                    2             0.0        1

# %%
reproduce_df.shape
# Out:
# (2111, 17)

# %%
#TABLE 2. Categorical-Categorical
#categorical-categorical
#https://thinkingneuron.com/how-to-visualize-the-relationship-between-two-categorical-variables-in-python/
#https://datagy.io/pandas-crosstab/
CrosstabResult=pd.crosstab(reproduce_df.Gender,reproduce_df.Obesity)
print(CrosstabResult)
# Out:
# Obesity    0    1    2    3    4    5    6
# Gender
# 0.0      173  141  145  103  156    2  323
# 1.0       99  146  145  187  195  295    1

# %%
reproduce_df.drop(['Transportation'], axis = 1)
# Out:
#       Gender   Age  Height  Weight  Family_History  Consumption_high_caloric  \
# 0        0.0  21.0  162.00    64.0               1                         0
# 1        0.0  21.0  152.00    56.0               1                         0
# 2        1.0  23.0  180.00    77.0               1                         0
# 3        1.0  27.0  180.00    87.0               0                         0
# 4        1.0  22.0  178.00    89.8               0                         0
# ...      ...   ...     ...     ...             ...                       ...
# 2106     0.0  21.0  171.07   131.4               1                         1
# 2107     0.0  22.0  174.86   133.7               1                         1
# 2108     0.0  22.5  175.22   133.7               1                         1
# 2109     0.0  24.4  173.94   133.3               1                         1
# 2110     0.0  23.7  173.88   133.5               1                         1
#
#       Consumption_vegetables  Main_meals  Food_between_meals  Smoke  \
# 0                        2.0         3.0                   2      0
# 1                        3.0         3.0                   2      1
# 2                        2.0         3.0                   2      0
# 3                        3.0         3.0                   2      0
# 4                        2.0         1.0                   2      0
# ...                      ...         ...                 ...    ...
# 2106                     3.0         3.0                   2      0
# 2107                     3.0         3.0                   2      0
# 2108                     3.0         3.0                   2      0
# 2109                     3.0         3.0                   2      0
# 2110                     3.0         3.0                   2      0
#
#       Consumption_water  Calories_monitoring  Physical_activity  \
# 0              2.000000                    0           0.000000
# 1              3.000000                    1           3.000000
# 2              2.000000                    0           2.000000
# 3              2.000000                    0           2.000000
# 4              2.000000                    0           0.000000
# ...                 ...                  ...                ...
# 2106           1.728139                    0           1.676269
# 2107           2.005130                    0           1.341390
# 2108           2.054193                    0           1.414209
# 2109           2.852339                    0           1.139107
# 2110           2.863513                    0           1.026452
#
#       Technology_devices  Consumption_alcohol  Obesity
# 0               1.000000                    1        1
# 1               0.000000                    2        1
# 2               1.000000                    3        1
# 3               0.000000                    3        2
# 4               0.000000                    2        3
# ...                  ...                  ...      ...
# 2106            0.906247                    2        6
# 2107            0.599270                    2        6
# 2108            0.646288                    2        6
# 2109            0.586035                    2        6
# 2110            0.714137                    2        6
#
# [2111 rows x 16 columns]

# %%
#TABLE 3. Definition of COVID-19 datase
#Definition of COVID-19 dataset
#https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.info.html
reproduce_df.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2111 entries, 0 to 2110
# Data columns (total 17 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Gender                    2111 non-null   float64
#  1   Age                       2111 non-null   float64
#  2   Height                    2111 non-null   float64
#  3   Weight                    2111 non-null   float64
#  4   Family_History            2111 non-null   int64
#  5   Consumption_high_caloric  2111 non-null   int64
#  6   Consumption_vegetables    2111 non-null   float64
#  7   Main_meals                2111 non-null   float64
#  8   Food_between_meals        2111 non-null   int64
#  9   Smoke                     2111 non-null   int64
#  10  Consumption_water         2111 non-null   float64
#  11  Calories_monitoring       2111 non-null   int64
#  12  Physical_activity         2111 non-null   float64
#  13  Technology_devices        2111 non-null   float64
#  14  Consumption_alcohol       2111 non-null   int64
#  15  Transportation            2111 non-null   float64
#  16  Obesity                   2111 non-null   int64
# dtypes: float64(10), int64(7)
# memory usage: 280.5 KB

# %%
reproduce_df.head(2)
# Out:
#    Gender   Age  Height  Weight  Family_History  Consumption_high_caloric  \
# 0     0.0  21.0   162.0    64.0               1                         0
# 1     0.0  21.0   152.0    56.0               1                         0
#
#    Consumption_vegetables  Main_meals  Food_between_meals  Smoke  \
# 0                     2.0         3.0                   2      0
# 1                     3.0         3.0                   2      1
#
#    Consumption_water  Calories_monitoring  Physical_activity  \
# 0                2.0                    0                0.0
# 1                3.0                    1                3.0
#
#    Technology_devices  Consumption_alcohol  Transportation  Obesity
# 0                 1.0                    1             3.0        1
# 1                 0.0                    2             3.0        1

# %%
#FIGURE 3. Categorical-Continous for Contact_with_covid_patient
#https://towardsdatascience.com/a-complete-guide-to-plotting-categorical-variables-with-seaborn-bfe54db66bec
plt.figure()
import seaborn as sns
sns.set(style="darkgrid")
sns.countplot(data = reproduce_df,x = 'Obesity')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="431.818172458775">

# %%
reproduce_df.head()
# Out:
#    Gender   Age  Height  Weight  Family_History  Consumption_high_caloric  \
# 0     0.0  21.0   162.0    64.0               1                         0
# 1     0.0  21.0   152.0    56.0               1                         0
# 2     1.0  23.0   180.0    77.0               1                         0
# 3     1.0  27.0   180.0    87.0               0                         0
# 4     1.0  22.0   178.0    89.8               0                         0
#
#    Consumption_vegetables  Main_meals  Food_between_meals  Smoke  \
# 0                     2.0         3.0                   2      0
# 1                     3.0         3.0                   2      1
# 2                     2.0         3.0                   2      0
# 3                     3.0         3.0                   2      0
# 4                     2.0         1.0                   2      0
#
#    Consumption_water  Calories_monitoring  Physical_activity  \
# 0                2.0                    0                0.0
# 1                3.0                    1                3.0
# 2                2.0                    0                2.0
# 3                2.0                    0                2.0
# 4                2.0                    0                0.0
#
#    Technology_devices  Consumption_alcohol  Transportation  Obesity
# 0                 1.0                    1             3.0        1
# 1                 0.0                    2             3.0        1
# 2                 1.0                    3             3.0        1
# 3                 0.0                    3             4.0        2
# 4                 0.0                    2             3.0        3

# %%
reproduce_df.columns

def col_no(x):
    d = {}
    d[reproduce_df.columns[x]] = x
    return(d)

print([col_no(x) for x in range(0, len(reproduce_df.columns))])
# Out:
# [{'Gender': 0}, {'Age': 1}, {'Height': 2}, {'Weight': 3}, {'Family_History': 4}, {'Consumption_high_caloric': 5}, {'Consumption_vegetables': 6}, {'Main_meals': 7}, {'Food_between_meals': 8}, {'Smoke': 9}, {'Consumption_water': 10}, {'Calories_monitoring': 11}, {'Physical_activity': 12}, {'Technology_devices': 13}, {'Consumption_alcohol': 14}, {'Transportation': 15}, {'Obesity': 16}]

# %% [markdown]
# Feature Selection

# %%
#TABLE 1. Patients information dataset
#glance at raw dataset first and last few rows 
reproduce_df.head(2)
# Out:
#    Gender   Age  Height  Weight  Family_History  Consumption_high_caloric  \
# 0     0.0  21.0   162.0    64.0               1                         0
# 1     0.0  21.0   152.0    56.0               1                         0
#
#    Consumption_vegetables  Main_meals  Food_between_meals  Smoke  \
# 0                     2.0         3.0                   2      0
# 1                     3.0         3.0                   2      1
#
#    Consumption_water  Calories_monitoring  Physical_activity  \
# 0                2.0                    0                0.0
# 1                3.0                    1                3.0
#
#    Technology_devices  Consumption_alcohol  Transportation  Obesity
# 0                 1.0                    1             3.0        1
# 1                 0.0                    2             3.0        1

# %%
plt.figure()
x=reproduce_df.iloc[:,0:15]
y=reproduce_df['Obesity']
from sklearn.ensemble import ExtraTreesClassifier
model = ExtraTreesClassifier()
model.fit(x, y)
print(model.feature_importances_)
feat_importances = pd.Series(model.feature_importances_, index=x.columns)
feat_importances.nlargest(10).plot.barh()
plt.savefig("natalie1107.png",bbox_inches='tight')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="392.7272642151385">
# [0.07753568 0.0901252  0.08212797 0.26137864 0.04884026 0.0266943
#  0.08010627 0.06512892 0.03999834 0.00472475 0.05268326 0.01287764
#  0.04992743 0.05380116 0.05405017]

# %% [markdown]
# # FIGURE 8. Obesity dataset feature selection
# #https://www.analyticsvidhya.com/blog/2021/04/discovering-the-shades-of-feature-selection-methods/
# plt.figure()
# X=reproduce_df.iloc[:,0:15]
# Y=reproduce_df['Obesity']
# from sklearn.ensemble import ExtraTreesClassifier
# model = ExtraTreesClassifier()
# model.fit(X, Y)
# print(model.feature_importances_)
# feat_importances = pd.Series(model.feature_importances_, index=X.columns)
# feat_importances.nlargest(16).plot.barh()
# plt.show()
# list1=feat_importances.keys().to_list()

# %%
#FIGURE 9. Correlation matrix of the dataset features

#https://likegeeks.com/python-correlation-matrix/
import pandas as pd
import numpy as np
import seaborn as sns
df_small = reproduce_df.iloc[:,0:17]  #independent columns
#get correlations of each features in dataset
corrmat = df_small.corr().round(2)
#plot heat map
fig, ax = plt.subplots(figsize=(15,15))         # Sample figsize in inches
gx=sns.heatmap(corrmat,annot=True,cmap="RdYlGn",linewidths=.5,annot_kws={"fontsize":20},ax=ax)

plt.show()
plt.savefig("heatmap_natalie.png")
# Out:
# <img src="data:image/png;base64,..." width="1079.999976591631">

# %%
#https://datatofish.com/correlation-matrix-pandas/
reproduce_df.corr().round(1)
# Out:
#                           Gender  Age  Height  Weight  Family_History  \
# Gender                       1.0  0.0     0.6     0.2             0.1
# Age                          0.0  1.0    -0.0     0.2             0.2
# Height                       0.6 -0.0     1.0     0.5             0.2
# Weight                       0.2  0.2     0.5     1.0             0.5
# Family_History               0.1  0.2     0.2     0.5             1.0
# Consumption_high_caloric     0.1  0.1     0.2     0.3             0.2
# Consumption_vegetables      -0.3  0.0    -0.0     0.2             0.0
# Main_meals                   0.1 -0.0     0.2     0.1             0.1
# Food_between_meals          -0.1 -0.1    -0.0    -0.3            -0.2
# Smoke                        0.0  0.1     0.1     0.0             0.0
# Consumption_water            0.1 -0.0     0.2     0.2             0.1
# Calories_monitoring         -0.1 -0.1    -0.1    -0.2            -0.2
# Physical_activity            0.2 -0.1     0.3    -0.1            -0.1
# Technology_devices           0.0 -0.3     0.1    -0.1             0.0
# Consumption_alcohol         -0.0  0.0     0.1     0.2            -0.0
# Transportation              -0.1 -0.6    -0.1     0.0            -0.1
# Obesity                     -0.0  0.3     0.1     0.9             0.5
#
#                           Consumption_high_caloric  Consumption_vegetables  \
# Gender                                         0.1                    -0.3
# Age                                            0.1                     0.0
# Height                                         0.2                    -0.0
# Weight                                         0.3                     0.2
# Family_History                                 0.2                     0.0
# Consumption_high_caloric                       1.0                    -0.0
# Consumption_vegetables                        -0.0                     1.0
# Main_meals                                    -0.0                     0.0
# Food_between_meals                            -0.2                     0.1
# Smoke                                         -0.1                     0.0
# Consumption_water                              0.0                     0.1
# Calories_monitoring                           -0.2                     0.1
# Physical_activity                             -0.1                     0.0
# Technology_devices                             0.1                    -0.1
# Consumption_alcohol                            0.1                     0.1
# Transportation                                -0.1                     0.1
# Obesity                                        0.2                     0.2
#
#                           Main_meals  Food_between_meals  Smoke  \
# Gender                           0.1                -0.1    0.0
# Age                             -0.0                -0.1    0.1
# Height                           0.2                -0.0    0.1
# Weight                           0.1                -0.3    0.0
# Family_History                   0.1                -0.2    0.0
# Consumption_high_caloric        -0.0                -0.2   -0.1
# Consumption_vegetables           0.0                 0.1    0.0
# Main_meals                       1.0                 0.1    0.0
# Food_between_meals               0.1                 1.0    0.1
# Smoke                            0.0                 0.1    1.0
# Consumption_water                0.1                -0.1   -0.0
# Calories_monitoring             -0.0                 0.1    0.0
# Physical_activity                0.1                 0.0    0.0
# Technology_devices               0.0                 0.0    0.0
# Consumption_alcohol              0.1                -0.0    0.1
# Transportation                  -0.1                 0.0   -0.0
# Obesity                          0.0                -0.3    0.0
#
#                           Consumption_water  Calories_monitoring  \
# Gender                                  0.1                 -0.1
# Age                                    -0.0                 -0.1
# Height                                  0.2                 -0.1
# Weight                                  0.2                 -0.2
# Family_History                          0.1                 -0.2
# Consumption_high_caloric                0.0                 -0.2
# Consumption_vegetables                  0.1                  0.1
# Main_meals                              0.1                 -0.0
# Food_between_meals                     -0.1                  0.1
# Smoke                                  -0.0                  0.0
# Consumption_water                       1.0                  0.0
# Calories_monitoring                     0.0                  1.0
# Physical_activity                       0.2                  0.1
# Technology_devices                      0.0                 -0.0
# Consumption_alcohol                     0.1                  0.0
# Transportation                          0.0                  0.0
# Obesity                                 0.1                 -0.2
#
#                           Physical_activity  Technology_devices  \
# Gender                                  0.2                 0.0
# Age                                    -0.1                -0.3
# Height                                  0.3                 0.1
# Weight                                 -0.1                -0.1
# Family_History                         -0.1                 0.0
# Consumption_high_caloric               -0.1                 0.1
# Consumption_vegetables                  0.0                -0.1
# Main_meals                              0.1                 0.0
# Food_between_meals                      0.0                 0.0
# Smoke                                   0.0                 0.0
# Consumption_water                       0.2                 0.0
# Calories_monitoring                     0.1                -0.0
# Physical_activity                       1.0                 0.1
# Technology_devices                      0.1                 1.0
# Consumption_alcohol                    -0.1                -0.0
# Transportation                          0.0                 0.2
# Obesity                                -0.2                -0.1
#
#                           Consumption_alcohol  Transportation  Obesity
# Gender                                   -0.0            -0.1     -0.0
# Age                                       0.0            -0.6      0.3
# Height                                    0.1            -0.1      0.1
# Weight                                    0.2             0.0      0.9
# Family_History                           -0.0            -0.1      0.5
# Consumption_high_caloric                  0.1            -0.1      0.2
# Consumption_vegetables                    0.1             0.1      0.2
# Main_meals                                0.1            -0.1      0.0
# Food_between_meals                       -0.0             0.0     -0.3
# Smoke                                     0.1            -0.0      0.0
# Consumption_water                         0.1             0.0      0.1
# Calories_monitoring                       0.0             0.0     -0.2
# Physical_activity                        -0.1             0.0     -0.2
# Technology_devices                       -0.0             0.2     -0.1
# Consumption_alcohol                       1.0             0.0      0.2
# Transportation                            0.0             1.0      0.0
# Obesity                                   0.2             0.0      1.0

# %% [markdown]
# METHODS(Train:Test at 0.8:0.2)

# %%
xx=reproduce_df[['Weight', 'Age', 'Gender', 'Consumption_vegetables','Height']].values
##xx=reproduce_df[['Weight', 'Age', 'Gender', 'Consumption_vegetables','Height']].values
##xx=reproduce_df[['Weight', 'Family_History', 'Age','Food_between_meals', 'Consumption_high_caloric', 'Consumption_vegetables']]
yy=reproduce_df['Obesity'].values

# %%
from sklearn.model_selection import train_test_split
#https://realpython.com/train-test-split-python-data/
x_train,x_test,y_train,y_test=train_test_split(xx,yy,test_size=0.2,random_state=0)
d=pd.DataFrame(x_train)

# %%
# logistic regression for multi-class classification using a one-vs-rest
#https://www.geeksforgeeks.org/one-vs-rest-strategy-for-multi-class-classification/
from sklearn.datasets import make_classification
from sklearn.linear_model import LogisticRegression
from sklearn.multiclass import OneVsRestClassifier
from sklearn.metrics import accuracy_score, classification_report, roc_curve, roc_auc_score
# define dataset
model0 = OneVsRestClassifier(LogisticRegression())
   
# Fitting the model with training data
model0.fit(x_train, y_train)
   
# Making a prediction on the test set
prediction0 = model0.predict(x_test)
y_prob_pred0 = model0.predict_proba(x_test)

#roc auc score
roc0=roc_auc_score(y_test, y_prob_pred0, multi_class='ovo', average='weighted')

# Evaluating the model
print(f"Test Set Accuracy for LR: {accuracy_score(y_test, prediction0)}")
print(f"Classification Report(LR) : \n\n{classification_report(y_test, prediction0)}")
# Out:
# Test Set Accuracy for LR: 0.7919621749408984
# Classification Report(LR) :
#
#               precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98        65
#            1       0.79      0.84      0.81        57
#            2       0.63      0.46      0.53        57
#            3       0.55      0.47      0.51        55
#            4       0.60      0.73      0.66        67
#            5       0.91      1.00      0.95        53
#            6       1.00      1.00      1.00        69
#
#     accuracy                           0.79       423
#    macro avg       0.78      0.78      0.78       423
# weighted avg       0.79      0.79      0.79       423

# %%
# roc curve for classes
fpr = {}
tpr = {}
thresh ={}

n_class = 7

for i in range(n_class):    
    fpr[i], tpr[i], thresh[i] = roc_curve(y_test, y_prob_pred0[:,i], pos_label=i)
    
roc0=roc_auc_score(y_test, y_prob_pred0, multi_class='ovo', average='weighted')

    
plt.figure()
print(f"The roc auc score for LR: {roc0}")

# plotting    
plt.plot(fpr[0], tpr[0], linestyle='--',color='orange', label='InsufficientWeight')
plt.plot(fpr[1], tpr[1], linestyle='--',color='green', label='NormalWeight')
plt.plot(fpr[2], tpr[2], linestyle='--',color='blue', label='OverweightLevelI')
plt.plot(fpr[3], tpr[3], linestyle='--',color='darkolivegreen', label='OverweightLevelII')
plt.plot(fpr[4], tpr[4], linestyle='--',color='purple', label='ObesityTypeI')
plt.plot(fpr[5], tpr[5], linestyle='--',color='red', label='ObesityTypeII')
plt.plot(fpr[6], tpr[6], linestyle='--',color='indigo', label='OverweightLevelII')
plt.title('Multiclass ROC curve (LR)')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive rate')
plt.legend(loc='best')
plt.savefig('Multiclass ROC (LR)',dpi=300);    
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="432">
# The roc auc score for LR: 0.9540828243962678

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
cm0 = confusion_matrix(y_test, prediction0 )
plt.figure()
sns.heatmap(cm0, annot=True, fmt='d', cmap='YlGnBu')
plt.ylabel('Actual label');
plt.xlabel('Predicted label');
# Out:
# <img src="data:image/png;base64,..." width="432">

# %%
from sklearn.svm import SVC


model1 = OneVsRestClassifier(SVC(probability=True))
   
# Fitting the model with training data
model1.fit(x_train, y_train)
   
# Making a prediction on the test set
prediction1 = model1.predict(x_test)
y_prob_pred1 = model1.predict_proba(x_test)


# Evaluating the model
print(f"Test Set Accuracy for SVM: {accuracy_score(y_test, prediction1)}")
print(f"Classification Report(SVM) : \n\n{classification_report(y_test, prediction1)}")
# Out:
# Test Set Accuracy for SVM: 0.6453900709219859
# Classification Report(SVM) :
#
#               precision    recall  f1-score   support
#
#            0       0.61      1.00      0.76        65
#            1       0.46      0.30      0.36        57
#            2       0.75      0.42      0.54        57
#            3       0.57      0.24      0.33        55
#            4       0.69      0.73      0.71        67
#            5       0.63      0.68      0.65        53
#            6       0.72      1.00      0.84        69
#
#     accuracy                           0.65       423
#    macro avg       0.63      0.62      0.60       423
# weighted avg       0.64      0.65      0.61       423

# %%
# roc curve for classes
fpr = {}
tpr = {}
thresh ={}

n_class = 7

for i in range(n_class):    
    fpr[i], tpr[i], thresh[i] = roc_curve(y_test, y_prob_pred1[:,i], pos_label=i)

plt.figure()
    
# plotting    
plt.plot(fpr[0], tpr[0], linestyle='--',color='orange', label='InsufficientWeight')
plt.plot(fpr[1], tpr[1], linestyle='--',color='green', label='NormalWeight')
plt.plot(fpr[2], tpr[2], linestyle='--',color='blue', label='OverweightLevelI')
plt.plot(fpr[3], tpr[3], linestyle='--',color='darkolivegreen', label='OverweightLevelII')
plt.plot(fpr[4], tpr[4], linestyle='--',color='purple', label='ObesityTypeI')
plt.plot(fpr[5], tpr[5], linestyle='--',color='red', label='ObesityTypeII')
plt.plot(fpr[6], tpr[6], linestyle='--',color='indigo', label='OverweightLevelII')
plt.title('Multiclass ROC curve (SVM)')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive rate')
plt.legend(loc='best')
plt.savefig('Multiclass ROC (SVM)',dpi=300);    
plt.show()
roc1=roc_auc_score(y_test, y_prob_pred1, multi_class='ovo', average='weighted')
print(f"The roc auc score for SVM: {roc1}")
# Out:
# <img src="data:image/png;base64,..." width="432">
# The roc auc score for SVM: 0.9810396312148467

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
cm1 = confusion_matrix(y_test, prediction1 )
plt.figure()
sns.heatmap(cm1, annot=True, fmt='d', cmap='YlGnBu')
plt.ylabel('Actual label');
plt.xlabel('Predicted label');
# Out:
# <img src="data:image/png;base64,..." width="432">

# %%
#https://www.vebuso.com/2020/03/svm-hyperparameter-tuning-using-gridsearchcv/
from sklearn.multiclass import OneVsRestClassifier
from sklearn.ensemble import RandomForestClassifier

model2 = OneVsRestClassifier(RandomForestClassifier())
   
# Fitting the model with training data
model2.fit(x_train, y_train)
   
# Making a prediction on the test set
prediction2 = model2.predict(x_test)
y_prob_pred2 = model2.predict_proba(x_test)



# Evaluating the model
print(f"Test Set Accuracy for RF: {accuracy_score(y_test, prediction2)}")
print(f"Classification Report(RF) : \n\n{classification_report(y_test, prediction2)}")
# Out:
# Test Set Accuracy for RF: 0.9739952718676123
# Classification Report(RF) :
#
#               precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98        65
#            1       0.95      0.98      0.97        57
#            2       0.96      0.91      0.94        57
#            3       0.94      0.93      0.94        55
#            4       0.97      1.00      0.99        67
#            5       1.00      1.00      1.00        53
#            6       1.00      1.00      1.00        69
#
#     accuracy                           0.97       423
#    macro avg       0.97      0.97      0.97       423
# weighted avg       0.97      0.97      0.97       423

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
cm2 = confusion_matrix(y_test, prediction2 )
plt.figure()
sns.heatmap(cm2, annot=True, fmt='d', cmap='YlGnBu')
plt.ylabel('Actual label');
plt.xlabel('Predicted label');
# Out:
# <img src="data:image/png;base64,..." width="432">

# %%
# roc curve for classes
fpr = {}
tpr = {}
thresh ={}

n_class = 7

for i in range(n_class):    
    fpr[i], tpr[i], thresh[i] = roc_curve(y_test, y_prob_pred2[:,i], pos_label=i)

plt.figure()
    
# plotting    
plt.plot(fpr[0], tpr[0], linestyle='--',color='orange', label='InsufficientWeight')
plt.plot(fpr[1], tpr[1], linestyle='--',color='green', label='NormalWeight')
plt.plot(fpr[2], tpr[2], linestyle='--',color='blue', label='OverweightLevelI')
plt.plot(fpr[3], tpr[3], linestyle='--',color='darkolivegreen', label='OverweightLevelII')
plt.plot(fpr[4], tpr[4], linestyle='--',color='purple', label='ObesityTypeI')
plt.plot(fpr[5], tpr[5], linestyle='--',color='red', label='ObesityTypeII')
plt.plot(fpr[6], tpr[6], linestyle='--',color='indigo', label='OverweightLevelII')
plt.title('Multiclass ROC curve (RF)')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive rate')
plt.legend(loc='best')
plt.savefig('Multiclass ROC (RF)',dpi=300);    
plt.show()
roc2=roc_auc_score(y_test, y_prob_pred2, multi_class='ovo', average='weighted')
print(f"The roc auc score for RF: {roc2}")
# Out:
# <img src="data:image/png;base64,..." width="432">
# The roc auc score for RF: 0.9992400905879428
