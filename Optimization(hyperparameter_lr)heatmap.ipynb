# %%
#Import the libary to deal with tabular data and visualization
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from IPython.display import display
pd.options.display.float_format = '{:,.2f}'.format

# %matplotlib inline
# %matplotlib notebook
#Import the dataset
reproduce_df = pd.read_csv('ObesityDataSet_raw_and_data_sinthetic.csv')
#reproduce_df=pd.read_csv('Madedata1.csv')

# %%
reproduce_df.columns = ['Gender', 'Age', 'Height', 'Weight', 'Family_History',
       'Consumption_high_caloric', 'Consumption_vegetables', 'Main_meals', 'Food_between_meals', 'Smoke', 'Consumption_water', 'Calories_monitoring', 'Physical_activity', 'Technology_devices',
       'Consumption_alcohol', 'Transportation', 'Obesity']

reproduce_df.head(32)
# Out:
#     Gender   Age  Height  Weight Family_History Consumption_high_caloric  \
# 0   Female 21.00    1.62   64.00            yes                       no
# 1   Female 21.00    1.52   56.00            yes                       no
# 2     Male 23.00    1.80   77.00            yes                       no
# 3     Male 27.00    1.80   87.00             no                       no
# 4     Male 22.00    1.78   89.80             no                       no
# 5     Male 29.00    1.62   53.00             no                      yes
# 6   Female 23.00    1.50   55.00            yes                      yes
# 7     Male 22.00    1.64   53.00             no                       no
# 8     Male 24.00    1.78   64.00            yes                      yes
# 9     Male 22.00    1.72   68.00            yes                      yes
# 10    Male 26.00    1.85  105.00            yes                      yes
# 11  Female 21.00    1.72   80.00            yes                      yes
# 12    Male 22.00    1.65   56.00             no                       no
# 13    Male 41.00    1.80   99.00             no                      yes
# 14    Male 23.00    1.77   60.00            yes                      yes
# 15  Female 22.00    1.70   66.00            yes                       no
# 16    Male 27.00    1.93  102.00            yes                      yes
# 17  Female 29.00    1.53   78.00             no                      yes
# 18  Female 30.00    1.71   82.00            yes                      yes
# 19  Female 23.00    1.65   70.00            yes                       no
# 20    Male 22.00    1.65   80.00            yes                       no
# 21  Female 52.00    1.69   87.00            yes                      yes
# 22  Female 22.00    1.65   60.00            yes                      yes
# 23  Female 22.00    1.60   82.00            yes                      yes
# 24    Male 21.00    1.85   68.00            yes                      yes
# 25    Male 20.00    1.60   50.00            yes                       no
# 26    Male 21.00    1.70   65.00            yes                      yes
# 27  Female 23.00    1.60   52.00             no                      yes
# 28    Male 19.00    1.75   76.00            yes                      yes
# 29    Male 23.00    1.68   70.00             no                      yes
# 30    Male 29.00    1.77   83.00             no                      yes
# 31  Female 31.00    1.58   68.00            yes                       no
#
#     Consumption_vegetables  Main_meals Food_between_meals Smoke  \
# 0                     2.00        3.00          Sometimes    no
# 1                     3.00        3.00          Sometimes   yes
# 2                     2.00        3.00          Sometimes    no
# 3                     3.00        3.00          Sometimes    no
# 4                     2.00        1.00          Sometimes    no
# 5                     2.00        3.00          Sometimes    no
# 6                     3.00        3.00          Sometimes    no
# 7                     2.00        3.00          Sometimes    no
# 8                     3.00        3.00          Sometimes    no
# 9                     2.00        3.00          Sometimes    no
# 10                    3.00        3.00         Frequently    no
# 11                    2.00        3.00         Frequently    no
# 12                    3.00        3.00          Sometimes    no
# 13                    2.00        3.00          Sometimes    no
# 14                    3.00        1.00          Sometimes    no
# 15                    3.00        3.00             Always    no
# 16                    2.00        1.00          Sometimes    no
# 17                    2.00        1.00          Sometimes    no
# 18                    3.00        4.00         Frequently   yes
# 19                    2.00        1.00          Sometimes    no
# 20                    2.00        3.00          Sometimes    no
# 21                    3.00        1.00          Sometimes   yes
# 22                    3.00        3.00          Sometimes    no
# 23                    1.00        1.00          Sometimes    no
# 24                    2.00        3.00          Sometimes    no
# 25                    2.00        4.00         Frequently   yes
# 26                    2.00        1.00         Frequently    no
# 27                    2.00        4.00         Frequently    no
# 28                    3.00        3.00          Sometimes    no
# 29                    2.00        3.00          Sometimes    no
# 30                    1.00        4.00         Frequently    no
# 31                    2.00        1.00          Sometimes    no
#
#     Consumption_water Calories_monitoring  Physical_activity  \
# 0                2.00                  no               0.00
# 1                3.00                 yes               3.00
# 2                2.00                  no               2.00
# 3                2.00                  no               2.00
# 4                2.00                  no               0.00
# 5                2.00                  no               0.00
# 6                2.00                  no               1.00
# 7                2.00                  no               3.00
# 8                2.00                  no               1.00
# 9                2.00                  no               1.00
# 10               3.00                  no               2.00
# 11               2.00                 yes               2.00
# 12               3.00                  no               2.00
# 13               2.00                  no               2.00
# 14               1.00                  no               1.00
# 15               2.00                 yes               2.00
# 16               1.00                  no               1.00
# 17               2.00                  no               0.00
# 18               1.00                  no               0.00
# 19               2.00                  no               0.00
# 20               2.00                  no               3.00
# 21               2.00                  no               0.00
# 22               2.00                  no               1.00
# 23               2.00                  no               0.00
# 24               2.00                  no               0.00
# 25               2.00                  no               3.00
# 26               2.00                  no               1.00
# 27               2.00                  no               2.00
# 28               2.00                 yes               3.00
# 29               2.00                  no               2.00
# 30               3.00                  no               0.00
# 31               1.00                  no               1.00
#
#     Technology_devices Consumption_alcohol         Transportation  \
# 0                 1.00                  no  Public_Transportation
# 1                 0.00           Sometimes  Public_Transportation
# 2                 1.00          Frequently  Public_Transportation
# 3                 0.00          Frequently                Walking
# 4                 0.00           Sometimes  Public_Transportation
# 5                 0.00           Sometimes             Automobile
# 6                 0.00           Sometimes              Motorbike
# 7                 0.00           Sometimes  Public_Transportation
# 8                 1.00          Frequently  Public_Transportation
# 9                 1.00                  no  Public_Transportation
# 10                2.00           Sometimes  Public_Transportation
# 11                1.00           Sometimes  Public_Transportation
# 12                0.00           Sometimes  Public_Transportation
# 13                1.00          Frequently             Automobile
# 14                1.00           Sometimes  Public_Transportation
# 15                1.00           Sometimes  Public_Transportation
# 16                0.00           Sometimes  Public_Transportation
# 17                0.00                  no             Automobile
# 18                0.00                  no             Automobile
# 19                0.00           Sometimes  Public_Transportation
# 20                2.00                  no                Walking
# 21                0.00                  no             Automobile
# 22                0.00           Sometimes             Automobile
# 23                2.00           Sometimes  Public_Transportation
# 24                1.00           Sometimes  Public_Transportation
# 25                2.00                  no  Public_Transportation
# 26                2.00              Always                Walking
# 27                1.00           Sometimes             Automobile
# 28                1.00           Sometimes  Public_Transportation
# 29                2.00          Frequently                Walking
# 30                1.00                  no              Motorbike
# 31                0.00           Sometimes  Public_Transportation
#
#                 Obesity
# 0         Normal_Weight
# 1         Normal_Weight
# 2         Normal_Weight
# 3    Overweight_Level_I
# 4   Overweight_Level_II
# 5         Normal_Weight
# 6         Normal_Weight
# 7         Normal_Weight
# 8         Normal_Weight
# 9         Normal_Weight
# 10       Obesity_Type_I
# 11  Overweight_Level_II
# 12        Normal_Weight
# 13       Obesity_Type_I
# 14        Normal_Weight
# 15        Normal_Weight
# 16  Overweight_Level_II
# 17       Obesity_Type_I
# 18  Overweight_Level_II
# 19   Overweight_Level_I
# 20  Overweight_Level_II
# 21       Obesity_Type_I
# 22        Normal_Weight
# 23       Obesity_Type_I
# 24        Normal_Weight
# 25        Normal_Weight
# 26        Normal_Weight
# 27        Normal_Weight
# 28        Normal_Weight
# 29        Normal_Weight
# 30   Overweight_Level_I
# 31  Overweight_Level_II

# %%
reproduce_df['Obesity'] = reproduce_df['Obesity'].apply(lambda x: x.replace('_', ''))
reproduce_df['Transportation'] = reproduce_df['Transportation'].apply(lambda x: x.replace('_', ' '))
reproduce_df['Height'] = reproduce_df['Height']*100
reproduce_df['Height'] = reproduce_df['Height'].round(2)
reproduce_df['Weight'] = reproduce_df['Weight'].round(1)
reproduce_df['Age'] = reproduce_df['Age'].round(1)

# %%
mapping1 = {'no':0, 'yes':1}
mapping2 = {'no':1,'Sometimes':2,'Frequently':3,'Always':4}
mapping3 = {'InsufficientWeight':0,'NormalWeight':1,'OverweightLevelI':2,'OverweightLevelII':3,'ObesityTypeI':4
,'ObesityTypeII':5,'ObesityTypeIII':6}

# %%
reproduce_df['Family_History'] = reproduce_df['Family_History'].replace(mapping1)
reproduce_df['Consumption_high_caloric'] = reproduce_df['Consumption_high_caloric'].replace(mapping1)
reproduce_df['Food_between_meals'] = reproduce_df['Food_between_meals'].replace(mapping2)
reproduce_df['Smoke'] = reproduce_df['Smoke'].replace(mapping1)
reproduce_df['Calories_monitoring'] = reproduce_df['Calories_monitoring'].replace(mapping1)
reproduce_df['Consumption_alcohol'] = reproduce_df['Consumption_alcohol'].replace(mapping2)
reproduce_df['Obesity'] = reproduce_df['Obesity'].replace(mapping3)

# %%
from sklearn.preprocessing import OrdinalEncoder

enc = OrdinalEncoder()
enc.fit(reproduce_df[["Gender","Transportation"]])
reproduce_df[["Gender","Transportation"]] = enc.transform(reproduce_df[["Gender","Transportation"]])
#le = LabelEncoder()
#reproduce_df.Gender= le.fit_transform(reproduce_df['Gender'])
#reproduce_df.Transportation= le.fit_transform(reproduce_df['Transportation'])
#reproduce_df.Obesity= le.fit_transform(reproduce_df['Obesity'])
#reproduce_df = pd.concat([reproduce_df,pd.get_dummies(reproduce_df.Transportation).add_prefix('Transportation')],axis=1)

# %%
xx=reproduce_df[['Weight', 'Family_History', 'Age','Consumption_high_caloric', 'Consumption_vegetables']].values
yy=reproduce_df['Obesity'].values

# %%
from sklearn.model_selection import train_test_split
#https://realpython.com/train-test-split-python-data/
x_train,x_test,y_train,y_test=train_test_split(xx,yy,test_size=0.2,random_state=0)
d=pd.DataFrame(x_train)

# %%
#https://www.vebuso.com/2020/03/svm-hyperparameter-tuning-using-gridsearchcv/
from sklearn.metrics import classification_report
from sklearn.linear_model import LogisticRegression
from sklearn.multiclass import OneVsRestClassifier

model1 = OneVsRestClassifier(LogisticRegression(C=100,solver='newton-cg',max_iter=300, tol=0.01))
   
# Fitting the model with training data
model1.fit(x_train, y_train)
   
# Making a prediction on the test set
prediction1 = model1.predict(x_test)


from sklearn import metrics
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, prediction1))
print(f"Classification Report : \n\n{classification_report(y_test, prediction1)}")
# Out:
# Accuracy: 0.6146572104018913
# Classification Report :
#
#               precision    recall  f1-score   support
#
#            0       0.73      0.91      0.81        65
#            1       0.59      0.35      0.44        57
#            2       0.51      0.32      0.39        57
#            3       0.42      0.31      0.36        55
#            4       0.42      0.64      0.51        67
#            5       0.83      0.64      0.72        53
#            6       0.78      1.00      0.87        69
#
#     accuracy                           0.61       423
#    macro avg       0.61      0.60      0.59       423
# weighted avg       0.61      0.61      0.60       423

# %%
#https://www.vebuso.com/2020/03/svm-hyperparameter-tuning-using-gridsearchcv/
from sklearn.multiclass import OneVsRestClassifier

model2 = OneVsRestClassifier(LogisticRegression(C=10,solver='newton-cg',max_iter=300, tol=0.1))
   
# Fitting the model with training data
model2.fit(x_train, y_train)
   
# Making a prediction on the test set
prediction2 = model2.predict(x_test)


from sklearn import metrics
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, prediction2))
print(f"Classification Report : \n\n{classification_report(y_test, prediction2)}")
# Out:
# Accuracy: 0.607565011820331
# Classification Report :
#
#               precision    recall  f1-score   support
#
#            0       0.73      0.91      0.81        65
#            1       0.59      0.35      0.44        57
#            2       0.52      0.30      0.38        57
#            3       0.44      0.33      0.37        55
#            4       0.42      0.61      0.50        67
#            5       0.82      0.62      0.71        53
#            6       0.72      1.00      0.84        69
#
#     accuracy                           0.61       423
#    macro avg       0.60      0.59      0.58       423
# weighted avg       0.60      0.61      0.59       423

# %%
#https://www.vebuso.com/2020/03/svm-hyperparameter-tuning-using-gridsearchcv/
from sklearn.multiclass import OneVsRestClassifier

model3 = OneVsRestClassifier(LogisticRegression(C=1,solver='newton-cg',max_iter=300, tol=0.1))
   
# Fitting the model with training data
model3.fit(x_train, y_train)
   
# Making a prediction on the test set
prediction3 = model3.predict(x_test)


from sklearn import metrics
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, prediction3))
print(f"Classification Report : \n\n{classification_report(y_test, prediction3)}")
# Out:
# Accuracy: 0.6122931442080378
# Classification Report :
#
#               precision    recall  f1-score   support
#
#            0       0.74      0.92      0.82        65
#            1       0.63      0.39      0.48        57
#            2       0.59      0.35      0.44        57
#            3       0.43      0.33      0.37        55
#            4       0.43      0.60      0.50        67
#            5       0.81      0.57      0.67        53
#            6       0.69      1.00      0.82        69
#
#     accuracy                           0.61       423
#    macro avg       0.62      0.59      0.58       423
# weighted avg       0.62      0.61      0.59       423

# %%
#https://www.vebuso.com/2020/03/svm-hyperparameter-tuning-using-gridsearchcv/
from sklearn.multiclass import OneVsRestClassifier

model4 = OneVsRestClassifier(LogisticRegression(C=0.1,solver='newton-cg',max_iter=300, tol=0.1))
   
# Fitting the model with training data
model4.fit(x_train, y_train)
   
# Making a prediction on the test set
prediction4 = model4.predict(x_test)


from sklearn import metrics
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, prediction4))
print(f"Classification Report : \n\n{classification_report(y_test, prediction4)}")
# Out:
# Accuracy: 0.6122931442080378
# Classification Report :
#
#               precision    recall  f1-score   support
#
#            0       0.74      0.95      0.83        65
#            1       0.61      0.40      0.48        57
#            2       0.61      0.33      0.43        57
#            3       0.35      0.29      0.32        55
#            4       0.46      0.58      0.51        67
#            5       0.82      0.58      0.68        53
#            6       0.68      1.00      0.81        69
#
#     accuracy                           0.61       423
#    macro avg       0.61      0.59      0.58       423
# weighted avg       0.61      0.61      0.59       423

# %%
#https://www.vebuso.com/2020/03/svm-hyperparameter-tuning-using-gridsearchcv/
from sklearn.multiclass import OneVsRestClassifier

model5 = OneVsRestClassifier(LogisticRegression(C=0.01,solver='newton-cg',max_iter=300, tol=0.1) )
   
# Fitting the model with training data
model5.fit(x_train, y_train)
   
# Making a prediction on the test set
prediction5 = model5.predict(x_test)


from sklearn import metrics
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, prediction5))
print(f"Classification Report : \n\n{classification_report(y_test, prediction5)}")
# Out:
# Accuracy: 0.607565011820331
# Classification Report :
#
#               precision    recall  f1-score   support
#
#            0       0.73      0.94      0.82        65
#            1       0.53      0.47      0.50        57
#            2       0.50      0.26      0.34        57
#            3       0.29      0.22      0.25        55
#            4       0.44      0.57      0.49        67
#            5       0.85      0.66      0.74        53
#            6       0.78      1.00      0.87        69
#
#     accuracy                           0.61       423
#    macro avg       0.59      0.59      0.58       423
# weighted avg       0.59      0.61      0.59       423

# %%
#https://www.vebuso.com/2020/03/svm-hyperparameter-tuning-using-gridsearchcv/
from sklearn.multiclass import OneVsRestClassifier

model6 = OneVsRestClassifier(LogisticRegression(C=100, solver="lbfgs",max_iter=300, tol=0.1))
   
# Fitting the model with training data
model6.fit(x_train, y_train)
   
# Making a prediction on the test set
prediction6 = model6.predict(x_test)


from sklearn import metrics
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, prediction6))
print(f"Classification Report : \n\n{classification_report(y_test, prediction6)}")
# Out:
# Accuracy: 0.6146572104018913
# Classification Report :
#
#               precision    recall  f1-score   support
#
#            0       0.73      0.91      0.81        65
#            1       0.59      0.35      0.44        57
#            2       0.51      0.32      0.39        57
#            3       0.42      0.31      0.36        55
#            4       0.42      0.64      0.51        67
#            5       0.83      0.64      0.72        53
#            6       0.78      1.00      0.87        69
#
#     accuracy                           0.61       423
#    macro avg       0.61      0.60      0.59       423
# weighted avg       0.61      0.61      0.60       423

# %%
#https://www.vebuso.com/2020/03/svm-hyperparameter-tuning-using-gridsearchcv/
from sklearn.multiclass import OneVsRestClassifier

model7 = OneVsRestClassifier(LogisticRegression(C=10, solver="lbfgs",max_iter=300, tol=0.1))
   
# Fitting the model with training data
model7.fit(x_train, y_train)
   
# Making a prediction on the test set
prediction7 = model7.predict(x_test)


from sklearn import metrics
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, prediction7))
print(f"Classification Report : \n\n{classification_report(y_test, prediction7)}")
# Out:
# Accuracy: 0.607565011820331
# Classification Report :
#
#               precision    recall  f1-score   support
#
#            0       0.73      0.91      0.81        65
#            1       0.59      0.35      0.44        57
#            2       0.52      0.30      0.38        57
#            3       0.44      0.33      0.37        55
#            4       0.42      0.61      0.50        67
#            5       0.82      0.62      0.71        53
#            6       0.72      1.00      0.84        69
#
#     accuracy                           0.61       423
#    macro avg       0.60      0.59      0.58       423
# weighted avg       0.60      0.61      0.59       423

# %%
#https://www.vebuso.com/2020/03/svm-hyperparameter-tuning-using-gridsearchcv/
from sklearn.multiclass import OneVsRestClassifier

model8 = OneVsRestClassifier(LogisticRegression(C=1, solver="lbfgs",max_iter=300, tol=0.1))
   
# Fitting the model with training data
model8.fit(x_train, y_train)
   
# Making a prediction on the test set
prediction8 = model8.predict(x_test)


from sklearn import metrics
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, prediction8))
print(f"Classification Report : \n\n{classification_report(y_test, prediction8)}")
# Out:
# Accuracy: 0.6099290780141844
# Classification Report :
#
#               precision    recall  f1-score   support
#
#            0       0.74      0.92      0.82        65
#            1       0.63      0.39      0.48        57
#            2       0.58      0.33      0.42        57
#            3       0.43      0.33      0.37        55
#            4       0.42      0.60      0.49        67
#            5       0.81      0.57      0.67        53
#            6       0.69      1.00      0.82        69
#
#     accuracy                           0.61       423
#    macro avg       0.61      0.59      0.58       423
# weighted avg       0.61      0.61      0.59       423

# %%
#https://www.vebuso.com/2020/03/svm-hyperparameter-tuning-using-gridsearchcv/
from sklearn.multiclass import OneVsRestClassifier

model9 = OneVsRestClassifier(LogisticRegression(C=0.1, solver="lbfgs",max_iter=300, tol=0.1))
   
# Fitting the model with training data
model9.fit(x_train, y_train)
   
# Making a prediction on the test set
prediction9 = model9.predict(x_test)


from sklearn import metrics
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, prediction9))
print(f"Classification Report : \n\n{classification_report(y_test, prediction9)}")
# Out:
# Accuracy: 0.6099290780141844
# Classification Report :
#
#               precision    recall  f1-score   support
#
#            0       0.74      0.95      0.83        65
#            1       0.59      0.40      0.48        57
#            2       0.61      0.33      0.43        57
#            3       0.33      0.27      0.30        55
#            4       0.46      0.58      0.51        67
#            5       0.82      0.58      0.68        53
#            6       0.68      1.00      0.81        69
#
#     accuracy                           0.61       423
#    macro avg       0.60      0.59      0.58       423
# weighted avg       0.61      0.61      0.59       423

# %%
#https://www.vebuso.com/2020/03/svm-hyperparameter-tuning-using-gridsearchcv/C
from sklearn.multiclass import OneVsRestClassifier

model10 = OneVsRestClassifier(LogisticRegression(C=0.01, solver="lbfgs",max_iter=300, tol=0.1))
   
# Fitting the model with training data
model10.fit(x_train, y_train)
   
# Making a prediction on the test set
prediction10 = model10.predict(x_test)


from sklearn import metrics
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, prediction10))
print(f"Classification Report : \n\n{classification_report(y_test, prediction10)}")
# Out:
# Accuracy: 0.607565011820331
# Classification Report :
#
#               precision    recall  f1-score   support
#
#            0       0.73      0.94      0.82        65
#            1       0.53      0.47      0.50        57
#            2       0.50      0.26      0.34        57
#            3       0.29      0.22      0.25        55
#            4       0.44      0.57      0.49        67
#            5       0.85      0.66      0.74        53
#            6       0.78      1.00      0.87        69
#
#     accuracy                           0.61       423
#    macro avg       0.59      0.59      0.58       423
# weighted avg       0.59      0.61      0.59       423

# %%
#https://www.vebuso.com/2020/03/svm-hyperparameter-tuning-using-gridsearchcv/
from sklearn.multiclass import OneVsRestClassifier

model11 = OneVsRestClassifier(LogisticRegression(C=100, solver="liblinear",max_iter=300, tol=0.1))
   
# Fitting the model with training data
model11.fit(x_train, y_train)
   
# Making a prediction on the test set
prediction11 = model11.predict(x_test)


from sklearn import metrics
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, prediction11))
print(f"Classification Report : \n\n{classification_report(y_test, prediction11)}")
# Out:
# Accuracy: 0.18203309692671396
# Classification Report :
#
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        65
#            1       0.00      0.00      0.00        57
#            2       0.00      0.00      0.00        57
#            3       0.16      0.15      0.15        55
#            4       0.09      0.28      0.14        67
#            5       0.21      0.32      0.25        53
#            6       0.42      0.48      0.45        69
#
#     accuracy                           0.18       423
#    macro avg       0.13      0.18      0.14       423
# weighted avg       0.13      0.18      0.15       423
# c:\users\cheng\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\cheng\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\cheng\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
#https://www.vebuso.com/2020/03/svm-hyperparameter-tuning-using-gridsearchcv/
from sklearn.multiclass import OneVsRestClassifier

model12 = OneVsRestClassifier(LogisticRegression(C=10, solver="liblinear",max_iter=300, tol=0.1) )
   
# Fitting the model with training data
model12.fit(x_train, y_train)
   
# Making a prediction on the test set
prediction12 = model12.predict(x_test)


from sklearn import metrics
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, prediction12))
print(f"Classification Report : \n\n{classification_report(y_test, prediction12)}")
# Out:
# Accuracy: 0.18203309692671396
# Classification Report :
#
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        65
#            1       0.00      0.00      0.00        57
#            2       0.00      0.00      0.00        57
#            3       0.16      0.15      0.15        55
#            4       0.09      0.28      0.14        67
#            5       0.21      0.32      0.25        53
#            6       0.42      0.48      0.45        69
#
#     accuracy                           0.18       423
#    macro avg       0.13      0.18      0.14       423
# weighted avg       0.13      0.18      0.15       423
# c:\users\cheng\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\cheng\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\cheng\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
#https://www.vebuso.com/2020/03/svm-hyperparameter-tuning-using-gridsearchcv/
from sklearn.multiclass import OneVsRestClassifier

model13 = OneVsRestClassifier(LogisticRegression(C=1, solver="liblinear",max_iter=300, tol=0.1))
   
# Fitting the model with training data
model13.fit(x_train, y_train)
   
# Making a prediction on the test set
prediction13 = model13.predict(x_test)


from sklearn import metrics
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, prediction13))
print(f"Classification Report : \n\n{classification_report(y_test, prediction13)}")
# Out:
# Accuracy: 0.18203309692671396
# Classification Report :
#
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        65
#            1       0.00      0.00      0.00        57
#            2       0.00      0.00      0.00        57
#            3       0.16      0.15      0.15        55
#            4       0.09      0.28      0.14        67
#            5       0.21      0.32      0.25        53
#            6       0.42      0.48      0.45        69
#
#     accuracy                           0.18       423
#    macro avg       0.13      0.18      0.14       423
# weighted avg       0.13      0.18      0.15       423
# c:\users\cheng\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\cheng\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\cheng\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
#https://www.vebuso.com/2020/03/svm-hyperparameter-tuning-using-gridsearchcv/
from sklearn.multiclass import OneVsRestClassifier

model14 = OneVsRestClassifier(LogisticRegression(C=0.1, solver="liblinear",max_iter=300, tol=0.1))
   
# Fitting the model with training data
model14.fit(x_train, y_train)
   
# Making a prediction on the test set
prediction14 = model14.predict(x_test)


from sklearn import metrics
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, prediction14))
print(f"Classification Report : \n\n{classification_report(y_test, prediction14)}")
# Out:
# Accuracy: 0.18203309692671396
# Classification Report :
#
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        65
#            1       0.00      0.00      0.00        57
#            2       0.00      0.00      0.00        57
#            3       0.16      0.15      0.15        55
#            4       0.09      0.28      0.14        67
#            5       0.21      0.32      0.25        53
#            6       0.42      0.48      0.45        69
#
#     accuracy                           0.18       423
#    macro avg       0.13      0.18      0.14       423
# weighted avg       0.13      0.18      0.15       423
# c:\users\cheng\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\cheng\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\cheng\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
#https://www.vebuso.com/2020/03/svm-hyperparameter-tuning-using-gridsearchcv/
from sklearn.multiclass import OneVsRestClassifier

model15 = OneVsRestClassifier(LogisticRegression(C=0.01, solver="liblinear",max_iter=300, tol=0.1))
   
# Fitting the model with training data
model15.fit(x_train, y_train)
   
# Making a prediction on the test set
prediction15 = model15.predict(x_test)


from sklearn import metrics
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, prediction15))
print(f"Classification Report : \n\n{classification_report(y_test, prediction15)}")
# Out:
# Accuracy: 0.17966903073286053
# Classification Report :
#
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        65
#            1       0.00      0.00      0.00        57
#            2       0.00      0.00      0.00        57
#            3       0.16      0.15      0.15        55
#            4       0.09      0.28      0.14        67
#            5       0.20      0.30      0.24        53
#            6       0.41      0.48      0.44        69
#
#     accuracy                           0.18       423
#    macro avg       0.12      0.17      0.14       423
# weighted avg       0.13      0.18      0.14       423
# c:\users\cheng\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\cheng\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\cheng\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
#https://www.vebuso.com/2020/03/svm-hyperparameter-tuning-using-gridsearchcv/
from sklearn.multiclass import OneVsRestClassifier

model16 = OneVsRestClassifier(LogisticRegression(C=100, solver="sag",max_iter=300, tol=0.1))
   
# Fitting the model with training data
model16.fit(x_train, y_train)
   
# Making a prediction on the test set
prediction16 = model16.predict(x_test)


from sklearn import metrics
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, prediction16))
print(f"Classification Report : \n\n{classification_report(y_test, prediction16)}")
# Out:
# Accuracy: 0.32860520094562645
# Classification Report :
#
#               precision    recall  f1-score   support
#
#            0       0.56      0.43      0.49        65
#            1       0.57      0.23      0.32        57
#            2       0.00      0.00      0.00        57
#            3       0.25      0.29      0.27        55
#            4       0.13      0.21      0.16        67
#            5       0.31      0.66      0.42        53
#            6       0.47      0.48      0.47        69
#
#     accuracy                           0.33       423
#    macro avg       0.33      0.33      0.31       423
# weighted avg       0.33      0.33      0.31       423
# c:\users\cheng\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\cheng\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\cheng\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
#https://www.vebuso.com/2020/03/svm-hyperparameter-tuning-using-gridsearchcv/
from sklearn.multiclass import OneVsRestClassifier

model17 = OneVsRestClassifier(LogisticRegression(C=10, solver="sag",max_iter=300, tol=0.1))
   
# Fitting the model with training data
model17.fit(x_train, y_train)
   
# Making a prediction on the test set
prediction17 = model17.predict(x_test)


from sklearn import metrics
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, prediction17))
print(f"Classification Report : \n\n{classification_report(y_test, prediction17)}")
# Out:
# Accuracy: 0.3120567375886525
# Classification Report :
#
#               precision    recall  f1-score   support
#
#            0       0.54      0.45      0.49        65
#            1       0.57      0.14      0.23        57
#            2       0.00      0.00      0.00        57
#            3       0.24      0.27      0.26        55
#            4       0.13      0.21      0.16        67
#            5       0.32      0.62      0.43        53
#            6       0.42      0.48      0.45        69
#
#     accuracy                           0.31       423
#    macro avg       0.32      0.31      0.29       423
# weighted avg       0.32      0.31      0.29       423

# %%
#https://www.vebuso.com/2020/03/svm-hyperparameter-tuning-using-gridsearchcv/
from sklearn.multiclass import OneVsRestClassifier

model18 = OneVsRestClassifier(LogisticRegression(C=1, solver="sag",max_iter=300, tol=0.1))
   
# Fitting the model with training data
model18.fit(x_train, y_train)
   
# Making a prediction on the test set
prediction18 = model18.predict(x_test)


from sklearn import metrics
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, prediction18))
print(f"Classification Report : \n\n{classification_report(y_test, prediction18)}")
# Out:
# Accuracy: 0.32860520094562645
# Classification Report :
#
#               precision    recall  f1-score   support
#
#            0       0.55      0.45      0.49        65
#            1       0.33      0.04      0.06        57
#            2       0.00      0.00      0.00        57
#            3       0.20      0.29      0.24        55
#            4       0.13      0.21      0.16        67
#            5       0.38      0.30      0.34        53
#            6       0.46      0.90      0.61        69
#
#     accuracy                           0.33       423
#    macro avg       0.29      0.31      0.27       423
# weighted avg       0.30      0.33      0.28       423

# %%
#https://www.vebuso.com/2020/03/svm-hyperparameter-tuning-using-gridsearchcv/
from sklearn.multiclass import OneVsRestClassifier

model19 = OneVsRestClassifier(LogisticRegression(C=0.1, solver="sag",max_iter=300, tol=0.1))
   
# Fitting the model with training data
model19.fit(x_train, y_train)
   
# Making a prediction on the test set
prediction19 = model19.predict(x_test)


from sklearn import metrics
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, prediction19))
print(f"Classification Report : \n\n{classification_report(y_test, prediction19)}")
# Out:
# Accuracy: 0.3262411347517731
# Classification Report :
#
#               precision    recall  f1-score   support
#
#            0       0.57      0.40      0.47        65
#            1       0.55      0.30      0.39        57
#            2       0.00      0.00      0.00        57
#            3       0.27      0.25      0.26        55
#            4       0.13      0.24      0.17        67
#            5       0.30      0.60      0.40        53
#            6       0.52      0.48      0.50        69
#
#     accuracy                           0.33       423
#    macro avg       0.33      0.32      0.31       423
# weighted avg       0.34      0.33      0.32       423
# c:\users\cheng\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\cheng\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\cheng\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
#https://www.vebuso.com/2020/03/svm-hyperparameter-tuning-using-gridsearchcv/
from sklearn.multiclass import OneVsRestClassifier

model20 = OneVsRestClassifier(LogisticRegression(C=0.01, solver="sag",max_iter=300, tol=0.1))
   
# Fitting the model with training data
model20.fit(x_train, y_train)
   
# Making a prediction on the test set
prediction20 = model20.predict(x_test)


from sklearn import metrics
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, prediction20))
print(f"Classification Report : \n\n{classification_report(y_test, prediction20)}")
# Out:
# Accuracy: 0.2789598108747045
# Classification Report :
#
#               precision    recall  f1-score   support
#
#            0       0.53      0.43      0.47        65
#            1       0.33      0.05      0.09        57
#            2       0.00      0.00      0.00        57
#            3       0.22      0.16      0.19        55
#            4       0.14      0.51      0.22        67
#            5       0.50      0.26      0.35        53
#            6       0.70      0.43      0.54        69
#
#     accuracy                           0.28       423
#    macro avg       0.35      0.26      0.26       423
# weighted avg       0.35      0.28      0.27       423
# c:\users\cheng\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\cheng\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\cheng\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
#https://www.vebuso.com/2020/03/svm-hyperparameter-tuning-using-gridsearchcv/
from sklearn.multiclass import OneVsRestClassifier

model21 = OneVsRestClassifier(LogisticRegression(C=100, solver="saga",max_iter=300, tol=0.1))
   
# Fitting the model with training data
model21.fit(x_train, y_train)
   
# Making a prediction on the test set
prediction21 = model21.predict(x_test)


from sklearn import metrics
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, prediction21))
print(f"Classification Report : \n\n{classification_report(y_test, prediction21)}")
# Out:
# Accuracy: 0.28368794326241137
# Classification Report :
#
#               precision    recall  f1-score   support
#
#            0       0.50      0.34      0.40        65
#            1       0.00      0.00      0.00        57
#            2       0.00      0.00      0.00        57
#            3       0.17      0.27      0.21        55
#            4       0.12      0.24      0.16        67
#            5       0.27      0.28      0.28        53
#            6       0.49      0.75      0.59        69
#
#     accuracy                           0.28       423
#    macro avg       0.22      0.27      0.23       423
# weighted avg       0.23      0.28      0.25       423
# c:\users\cheng\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\cheng\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\cheng\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
#https://www.vebuso.com/2020/03/svm-hyperparameter-tuning-using-gridsearchcv/
from sklearn.multiclass import OneVsRestClassifier

model22 = OneVsRestClassifier(LogisticRegression(C=10, solver="saga",max_iter=300, tol=0.1))
   
# Fitting the model with training data
model22.fit(x_train, y_train)
   
# Making a prediction on the test set
prediction22 = model22.predict(x_test)


from sklearn import metrics
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, prediction22))
print(f"Classification Report : \n\n{classification_report(y_test, prediction22)}")
# Out:
# Accuracy: 0.29314420803782504
# Classification Report :
#
#               precision    recall  f1-score   support
#
#            0       0.54      0.38      0.45        65
#            1       0.00      0.00      0.00        57
#            2       0.00      0.00      0.00        57
#            3       0.18      0.27      0.21        55
#            4       0.11      0.21      0.15        67
#            5       0.29      0.36      0.32        53
#            6       0.50      0.74      0.59        69
#
#     accuracy                           0.29       423
#    macro avg       0.23      0.28      0.25       423
# weighted avg       0.24      0.29      0.26       423
# c:\users\cheng\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\cheng\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\cheng\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
#https://www.vebuso.com/2020/03/svm-hyperparameter-tuning-using-gridsearchcv/
from sklearn.multiclass import OneVsRestClassifier

model23 = OneVsRestClassifier(LogisticRegression(C=1, solver="saga",max_iter=300, tol=0.1))
   
# Fitting the model with training data
model23.fit(x_train, y_train)
   
# Making a prediction on the test set
prediction23 = model23.predict(x_test)


from sklearn import metrics
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, prediction23))
print(f"Classification Report : \n\n{classification_report(y_test, prediction23)}")
# Out:
# Accuracy: 0.2718676122931442
# Classification Report :
#
#               precision    recall  f1-score   support
#
#            0       0.47      0.29      0.36        65
#            1       0.47      0.14      0.22        57
#            2       0.00      0.00      0.00        57
#            3       0.20      0.27      0.23        55
#            4       0.12      0.24      0.16        67
#            5       0.27      0.45      0.34        53
#            6       0.45      0.48      0.46        69
#
#     accuracy                           0.27       423
#    macro avg       0.28      0.27      0.25       423
# weighted avg       0.29      0.27      0.26       423
# c:\users\cheng\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\cheng\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\cheng\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
#https://www.vebuso.com/2020/03/svm-hyperparameter-tuning-using-gridsearchcv/
from sklearn.multiclass import OneVsRestClassifier

model24 = OneVsRestClassifier(LogisticRegression(C=0.1, solver="saga",max_iter=300, tol=0.1))
   
# Fitting the model with training data
model24.fit(x_train, y_train)
   
# Making a prediction on the test set
prediction24 = model24.predict(x_test)


from sklearn import metrics
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, prediction24))
print(f"Classification Report : \n\n{classification_report(y_test, prediction24)}")
# Out:
# Accuracy: 0.25295508274231676
# Classification Report :
#
#               precision    recall  f1-score   support
#
#            0       0.51      0.34      0.41        65
#            1       0.00      0.00      0.00        57
#            2       0.00      0.00      0.00        57
#            3       0.17      0.27      0.21        55
#            4       0.12      0.22      0.15        67
#            5       0.25      0.42      0.31        53
#            6       0.43      0.48      0.45        69
#
#     accuracy                           0.25       423
#    macro avg       0.21      0.25      0.22       423
# weighted avg       0.22      0.25      0.23       423
# c:\users\cheng\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\cheng\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\cheng\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
#https://www.vebuso.com/2020/03/svm-hyperparameter-tuning-using-gridsearchcv/
from sklearn.multiclass import OneVsRestClassifier

model25 = OneVsRestClassifier(LogisticRegression(C=0.01, solver="saga",max_iter=300, tol=0.1))
   
# Fitting the model with training data
model25.fit(x_train, y_train)
   
# Making a prediction on the test set
prediction25 = model25.predict(x_test)


from sklearn import metrics
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, prediction25))
print(f"Classification Report : \n\n{classification_report(y_test, prediction25)}")
# Out:
# Accuracy: 0.2576832151300236
# Classification Report :
#
#               precision    recall  f1-score   support
#
#            0       0.47      0.29      0.36        65
#            1       0.00      0.00      0.00        57
#            2       0.00      0.00      0.00        57
#            3       0.16      0.27      0.21        55
#            4       0.12      0.22      0.16        67
#            5       0.28      0.51      0.36        53
#            6       0.48      0.48      0.48        69
#
#     accuracy                           0.26       423
#    macro avg       0.22      0.25      0.22       423
# weighted avg       0.23      0.26      0.23       423
# c:\users\cheng\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\cheng\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\cheng\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
